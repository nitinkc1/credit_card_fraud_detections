# %%
pip install opendatasets

# %%
# Importing the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import opendatasets as od
pd.pandas.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings("ignore")

# %%
od.download('https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud')

# %%
data_file_name='./creditcardfraud/creditcard.csv'

# %% [markdown]
# **Data Preprocessing**

# %%
# Reading the dataset
credit_card_fraud=pd.read_csv(data_file_name)

# %%
credit_card_fraud.shape
# Out:
# (284807, 31)

# %%
credit_card_fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_fraud.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
credit_card_fraud.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
credit_card_fraud.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  4.356170 -1.593105  2.711941
# 284803  1.058415  0.024330  0.294869  0.584800 -0.975926 -0.150189  0.915802
# 284804  3.031260 -0.296827  0.708417  0.432454 -0.484782  0.411614  0.063119
# 284805  0.623708 -0.686180  0.679145  0.392087 -0.399126 -1.933849 -0.962886
# 284806 -0.649617  1.577006 -0.414650  0.486180 -0.915427 -1.040458 -0.031513
#
#              V13       V14       V15       V16       V17       V18       V19  \
# ...

# %%
credit_card_fraud.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# **Handle missing values**

# %%
# Cheking missing values in columns
credit_card_fraud.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_fraud.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# **Outliers treatment**
#
# We will not performing any outliers treatment for this  credit card fraud dataset. Because all the columns are already PCA transformed, which assumed that the outlier values are taken care while transforming the data.

# %%
legit=credit_card_fraud[credit_card_fraud['Class']==0]
fraud=credit_card_fraud[credit_card_fraud['Class']==1]
print(legit.shape,fraud.shape)
# Out:
# (284315, 31) (492, 31)

# %%
class_count=pd.value_counts(credit_card_fraud['Class'])
class_count.plot(kind='bar',color=['green','red'])
plt.title('Transaction class Distribution \n (0: legit class || 1: Fraud class)',fontsize=14)
plt.xlabel('Class')
plt.xticks(rotation='horizontal')
plt.ylabel('count')
for i, count in enumerate(class_count):
    plt.text(i, count, str(count), ha='center', va='bottom')
plt.show()

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %% [markdown]
# **Distribution of classes with Amount**

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
bins=50
plt.suptitle('Amount per transaction by class')

plt.hist(legit.Amount,bins=bins)
plt.title('Legit Transaction ')
plt.yscale('log')
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')


plt.subplot(1,2,2)
plt.hist(fraud.Amount,bins=bins)
plt.title('Fraud Transaction ')
plt.xlabel('Amount ($)')
plt.yscale('log')
plt.ylabel('Number of Transactions')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Analysis**
#
# We can see that the fraud transctions are mostly densed in the lower range of amount, whereas the non-fraud transctions are spreaded throughout low to high range of amount.

# %%
Amount_values=credit_card_fraud['Amount'].values
Time_values=credit_card_fraud['Time'].values

plt.figure(figsize=(10,4))

plt.subplot(1, 2, 1)
sns.distplot(Amount_values, color='red')
plt.title('Distribution of Transaction Amount')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
sns.distplot(Time_values,color='green')
plt.title('Distribution of Transaction Time')
plt.xlabel('Transaction Time')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Train-Test Split**

# %%
# Import library
from sklearn.model_selection import train_test_split

# %%
X = credit_card_fraud.drop(['Class'], axis=1)   # Putting feature variables into X
y = credit_card_fraud['Class']                 # Putting target variable to y

# %%
# Splitting data into train and test set 67:33
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.67, test_size=0.33, random_state=100)

# %% [markdown]
# **Feature Scaling**

# %% [markdown]
# we have to perform scaling operation only on Amount column as all other column are already scaled by PCA transformation

# %%
# Standardization method
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate the Scaler
scaler = StandardScaler()

# %%
# Fit the data into scaler and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])

# %%
X_train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 75921    56309.0  0.727945 -0.253614  0.951309  2.596187 -0.806780 -0.105885
# 158214  111093.0  2.095880  0.065258 -1.431455  0.312769  0.440517 -0.627421
# 242531  151532.0  2.208093 -1.523362 -0.455014 -1.433948 -1.634187 -0.557319
# 3002      2552.0  0.527645 -1.867609 -0.406808 -0.080770 -1.328165 -0.893759
# 230474  146344.0 -1.293583  0.503203  1.627809  2.426906 -0.818373  1.324429
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 75921  -0.073429  0.145870 -0.626549  0.765450  1.143839  0.033947 -1.254873
# 158214  0.048422 -0.327947  2.062684 -0.476309 -0.012147 -2.316512  1.694046
# 242531 -1.404013 -0.153666 -1.022408  1.524227 -0.678353 -0.361081  1.203207
# 3002    0.398017 -0.429082 -0.892784  0.403790 -0.686422  0.127537  0.500425
# 230474  0.560133  0.024880 -1.035326  1.425785 -1.085179 -1.911149 -1.091874
#
# ...

# %% [markdown]
# Now Scaling the test case

# %%
# Transform the test set
X_test['Amount'] = scaler.transform(X_test[['Amount']])
X_test.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 49089    43906.0  1.229452 -0.235478 -0.627166  0.419877  1.797014  4.069574
# 154704  102638.0  2.016893 -0.088751 -2.989257 -0.142575  2.675427  3.332289
# 67247    52429.0  0.535093 -1.469185  0.868279  0.385462 -1.439135  0.368118
# 251657  155444.0  2.128486 -0.117215 -1.513910  0.166456  0.359070 -0.540072
# 201903  134084.0  0.558593  1.587908 -2.368767  5.124413  2.171788 -0.500419
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 49089  -0.896223  1.036103  0.745991 -0.147304 -0.850459  0.397845 -0.259849
# 154704 -0.652336  0.752811  1.962566 -1.025024  1.126976 -2.418093  1.250341
# 67247  -0.499370  0.303698  1.042073 -0.437209  1.145725  0.907573 -1.095634
# 251657  0.116023 -0.216140  0.680314  0.079977 -1.705327 -0.127579 -0.207945
# 201903  1.059829 -0.254233 -1.959060  0.948915 -0.288169 -1.007647  0.470316
#
# ...

# %% [markdown]
# **MACHINE LEARNING MODELS**

# %%
# Impoting metrics from scikit
from sklearn import metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, f1_score,roc_auc_score

# %%
results = pd.DataFrame(columns=['Model Name', 'Accuracy', 'F1-score', 'ROC'])

# %%
# ROC Curve function
def draw_roc( actual, probs ):
    fpr, tpr, thresholds = metrics.roc_curve( actual, probs,
                                              drop_intermediate = False )
    auc_score = metrics.roc_auc_score( actual, probs )
    plt.figure(figsize=(5, 5))
    plt.plot( fpr, tpr, label='ROC curve (area = %0.2f)' % auc_score )
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate or [1 - True Negative Rate]')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic example')
    plt.legend(loc="lower right")
    plt.show()

    return None

# %% [markdown]
# **Logistic regression**

# %%
# Importing scikit logistic regression module
from sklearn.linear_model import LogisticRegression

# %%
# model with best C
logistic = LogisticRegression(C=0.01)

# %%
# Fit the model on the train set
logistic_model = logistic.fit(X_train, y_train)

# %%
# Prepare results function
def display_test_results(model_name, model):

    # Prediction on the test set
    y_test_pred = model.predict(X_test)

    # Confusion matrix
    print("------------------ Confusion Matrix --------------------")
    c_matrix = metrics.confusion_matrix(y_test, y_test_pred)
    print(c_matrix)

    cm_display = ConfusionMatrixDisplay(confusion_matrix=c_matrix)
    cm_display.plot(cmap=plt.cm.Blues)
    plt.show()

    roc_auc = roc_auc_score(y_test, y_test_pred)


    # classification_report
    print("------------------ classification_report --------------------")
    print(classification_report(y_test, y_test_pred))

    print("------------------ More Specific classification_report --------------------")
    TP = c_matrix[1,1] # true positive
    TN = c_matrix[0,0] # true negatives
    FP = c_matrix[0,1] # false positives
    FN = c_matrix[1,0] # false negatives

    # Accuracy
    print("Accuracy:-",metrics.accuracy_score(y_test, y_test_pred))

    # Sensitivity
    print("Sensitivity:-",TP / float(TP+FN))

    # Specificity
    print("Specificity:-", TN / float(TN+FP))

    # Roc score
    print("Roc score:-",roc_auc_score(y_test, y_test_pred))

    # F1 score
    print("F1-Score:-", f1_score(y_test, y_test_pred))

    # Predicted probability
    y_test_pred_proba = model.predict_proba(X_test)[:,1]

    # Plot the ROC curve
    draw_roc(y_test, y_test_pred_proba)

    # add all metrics score in final result store
    results.loc[len(results)] = [model_name, metrics.accuracy_score(y_test, y_test_pred), f1_score(y_test, y_test_pred),roc_auc]

    return None

# %% [markdown]
# **Prediction results**

# %%
display_test_results('Logistic Regression',logistic_model)
# Out:
# ------------------ Confusion Matrix --------------------
# [[76161 17673]
#  [   29   124]]
# ------------------ classification_report --------------------
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     93834
#            1       0.01      0.81      0.01       153
#
#     accuracy                           0.81     93987
#    macro avg       0.50      0.81      0.45     93987
# weighted avg       1.00      0.81      0.89     93987
#
# ------------------ More Specific classification_report --------------------
# Accuracy:- 0.811654803323864
# Sensitivity:- 0.8104575163398693
# Specificity:- 0.8116567555470299
# Roc score:- 0.8110571359434495
# F1-Score:- 0.013816155988857938

# %% [markdown]
# **Decision tree**

# %%
# Importing decision tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Model with optimal hyperparameters
decision_tree_model = DecisionTreeClassifier(criterion = "gini",
                                  random_state = 100,
                                  max_depth=5,
                                  min_samples_leaf=100,
                                  min_samples_split=100)

decision_tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100,
#                        random_state=100)

# %% [markdown]
# **Prediction results**

# %%
display_test_results("Decision Tree", decision_tree_model)
# Out:
# ------------------ Confusion Matrix --------------------
# [[93787    47]
#  [   57    96]]
# ------------------ classification_report --------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93834
#            1       0.67      0.63      0.65       153
#
#     accuracy                           1.00     93987
#    macro avg       0.84      0.81      0.82     93987
# weighted avg       1.00      1.00      1.00     93987
#
# ------------------ More Specific classification_report --------------------
# Accuracy:- 0.9988934639897007
# Sensitivity:- 0.6274509803921569
# Specificity:- 0.9994991154592152
# Roc score:- 0.813475047925686
# F1-Score:- 0.6486486486486487

# %% [markdown]
# **Random forest**

# %%
# Importing random forest classifier
from sklearn.ensemble import RandomForestClassifier

# %%
random_forest_model = RandomForestClassifier(bootstrap=True,
                             max_depth=5,
                             min_samples_leaf=50,
                             min_samples_split=50,
                             max_features=10,
                             n_estimators=100)

# %%
# Fit the model
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=10, min_samples_leaf=50,
#                        min_samples_split=50)

# %%
display_test_results("Random Forest", random_forest_model)
# Out:
# ------------------ Confusion Matrix --------------------
# [[93806    28]
#  [   49   104]]
# ------------------ classification_report --------------------
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     93834
#            1       0.79      0.68      0.73       153
#
#     accuracy                           1.00     93987
#    macro avg       0.89      0.84      0.86     93987
# weighted avg       1.00      1.00      1.00     93987
#
# ------------------ More Specific classification_report --------------------
# Accuracy:- 0.9991807377616053
# Sensitivity:- 0.6797385620915033
# Specificity:- 0.999701600699107
# Roc score:- 0.8397200813953051
# F1-Score:- 0.7298245614035088

# %% [markdown]
# **final summary**

# %%
results.sort_values(by="ROC", ascending=False)
# Out:
#             Model Name  Accuracy  F1-score       ROC
# 2        Random Forest  0.999181  0.729825  0.839720
# 1        Decision Tree  0.998893  0.648649  0.813475
# 0  Logistic Regression  0.811655  0.013816  0.811057
